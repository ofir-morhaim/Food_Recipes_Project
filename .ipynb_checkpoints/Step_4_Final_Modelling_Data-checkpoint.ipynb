# %%
import numpy as np
import pandas as pd
from sklearn import metrics
from sklearn.model_selection import train_test_split
import re
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

from sklearn.naive_bayes import GaussianNB

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression

import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
# %matplotlib inline
import statsmodels.api as sm
import tkinter as tk 
import seaborn as sns
from sklearn import tree

from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg

# %%
df_Ingrediants = pd.read_csv("Ingredients.csv")
df_CleanTable = pd.read_csv("Final_clean_project_data_Recipe_table.csv")
df_range = pd.read_csv("Rating_categorial.csv")

# %%
feature_cols = ['Preparation time in mins', 'Ingredients number','Calories per serving']
X = df_CleanTable[feature_cols] # Features
y = df_CleanTable.Rating_categorial

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.6,random_state=1)

logreg = LogisticRegression()

# fit the model with data
logreg.fit(X_train,y_train)
y_pred=logreg.predict(X_test)



cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
cnf_matrix


class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')


print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Precision:", metrics.accuracy_score(y_test, y_pred))
print("Recall:",metrics.recall_score(y_test, y_pred))

df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df
# Out:
# Accuracy: 0.6080187673277885
# Precision: 0.6080187673277885
# Recall: 0.9996493688639552
#       Actual  Predicted
# 4939       1          1
# 5113       1          1
# 7565       0          1
# 39         0          1
# 299        1          1
# ...      ...        ...
# 764        0          1
# 6549       0          1
# 4155       1          1
# 5239       0          1
# 7268       1          1
#
# [4689 rows x 2 columns]

# %%
df_CleanTable
# Out:
#       Unnamed: 0                                             Name  Rating  \
# 0              0                                Best Banana Bread    96.2
# 1              1                                  Bourbon Chicken    91.8
# 2              2                 Jo Mama's World Famous Spaghetti    94.6
# 3              3                       Creamy Cajun Chicken Pasta    96.8
# 4              4                                       Beer Bread    95.8
# ...          ...                                              ...     ...
# 7810       12528                             Souped up Tortellini    96.0
# 7811       12541                                    Whipped Cream    98.6
# 7812       12564           Mean Chef's Pineapple Upside-Down Cake    97.0
# 7813       12571                            Ham and  Corn Chowder    94.0
# 7814       12576  Kittencal's Best Deep Dark Chocolate Layer Cake    94.6
#
#       Rank number  Preparation time in mins  Ingredients number  \
# ...

# %%
X = df_CleanTable["Rating"] # Features 
y = df_CleanTable.Calories_categorial

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size= 0.25, random_state=1)

x_train= x_train.values.reshape(-1, 1)
y_train= y_train.values.reshape(-1, 1)
x_test = x_test.values.reshape(-1, 1)

classifier = GaussianNB()
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)

ac = metrics.accuracy_score(y_test,y_pred)
cm = metrics.confusion_matrix(y_test, y_pred)

print("Accuracy:",ac)

class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Accuracy: 0.6248720573183214
# C:\Users\OMorhaim\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# Text(0.5, 257.44, 'Predicted label')

# %%
df_binary500 = df_CleanTable[:][:]

sns.scatterplot(x ="Category", y ="Rank number", data = df_binary500) 

df_binary = df_CleanTable[['Category', 'Rank number']] 
  
df_binary.columns = ['Category', 'Rank number'] 
   
X = np.array(df_binary500['Category']).reshape(-1, 1) 
y = np.array(df_binary500['Rank number']).reshape(-1, 1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

regr = LinearRegression() 
regr.fit(X_train, y_train)

train_score = regr.score(X_train, y_train)
print("The training score of model is: ", train_score)
test_score = regr.score(X_test, y_test)
print("The score of the model on test data is:", test_score )
y_pred = regr.predict(X_test) 
plt.scatter(X_test, y_test, color ='b') 
plt.plot(X_test, y_pred, color ='k') 
  
plt.show()
# Out:
# The training score of model is:  0.0001521787526201912
# The score of the model on test data is: -0.0050689994414439

# %%
feature_cols = ['Preparation time in mins', 'Ingredients number','Calories per serving']
X = df_CleanTable[feature_cols] # Features
y = df_CleanTable.Rating_categorial

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.6,random_state=1)

logreg = LogisticRegression()

# fit the model with data
logreg.fit(X_train,y_train)
y_pred=logreg.predict(X_test)



cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
cnf_matrix


class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')


print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Precision:", metrics.accuracy_score(y_test, y_pred))
print("Recall:",metrics.recall_score(y_test, y_pred))

df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df
# Out:
# Accuracy: 0.6080187673277885
# Precision: 0.6080187673277885
# Recall: 0.9996493688639552
#       Actual  Predicted
# 4939       1          1
# 5113       1          1
# 7565       0          1
# 39         0          1
# 299        1          1
# ...      ...        ...
# 764        0          1
# 6549       0          1
# 4155       1          1
# 5239       0          1
# 7268       1          1
#
# [4689 rows x 2 columns]

# %%
X = df_CleanTable[['Preparation time in mins', 'Ingredients number','Calories per serving']] # here we have 2 variables for multiple regression. If you just want to use one variable for simple linear regression, then use X = df['Interest_Rate'] for example.Alternatively, you may add additional variables within the brackets
Y = df_CleanTable["Rating_categorial"]

# tkinter GUI
root= tk.Tk()

canvas1 = tk.Canvas(root, width = 400, height = 300)
canvas1.pack()

# with sklearn
Intercept_result = ('Successful prediction percentages: ')
label_Intercept = tk.Label(root, text=Intercept_result)
canvas1.create_window(100, 230, window=label_Intercept)
# with sklearn
per =int(metrics.accuracy_score(y_test, y_pred) *1000)
per=float(per)/10
Intercept_result = per
label_Intercept = tk.Label(root, text=Intercept_result)
canvas1.create_window(210, 230, window=label_Intercept)


# New_Interest_Rate label and input box
label1 = tk.Label(root, text='Type Preparation Time (in mins): ')
canvas1.create_window(100, 80, window=label1)

# New_Unemployment_Rate label and input box
label2 = tk.Label(root, text='Type Ingredients Number: ')
canvas1.create_window(100, 100, window=label2)

# New_Unemployment_Rate label and input box
label3 = tk.Label(root, text='Type Calories Number (optional): ')
canvas1.create_window(100, 120, window=label3)


entry1 = tk.Entry (root) # create 1st entry box
canvas1.create_window(270, 80, window=entry1)

entry2 = tk.Entry (root) # create 2nd entry box
canvas1.create_window(270, 100, window=entry2)

entry3 = tk.Entry (root) # create 2nd entry box
canvas1.create_window(270, 120, window=entry3)

def values(): 
    global Num_of_Time #our 1st input variable
    Num_of_Time = float(entry1.get()) 
    
    global Num_of_Ingre #our 2nd input variable
    Num_of_Ingre = float(entry2.get()) 
    
    global Num_of_Calories #our 2nd input variable
    try:
        Num_of_Calories = float(entry3.get()) 
    except:
        Num_of_Calories=0
    Rating_result  =logreg.predict([[Num_of_Time ,Num_of_Ingre,Num_of_Calories]])
    if Rating_result==1:
        Prediction_result  = ('Wow !! \nAre you a chef?! \n      The dish sounds great, and we know it will be a success story   ;)')
        label_Prediction = tk.Label(root, text= Prediction_result, bg='light green')

    else:
        Prediction_result  = ('An interesting recipe, \n    But unfortunately, we do not guarantee that the recipe will be popular.')
        label_Prediction = tk.Label(root, text= Prediction_result, bg='red')
    canvas1.create_window(180, 280, window=label_Prediction)

button1 = tk.Button (root, text='Ceack Your Recipe',command=values, bg='orange') # button to call the 'values' command above 
canvas1.create_window(200, 170, window=button1)
 


root.mainloop()
