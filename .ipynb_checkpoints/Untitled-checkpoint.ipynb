# %%
import numpy as np
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
# %matplotlib inline

# %%
df_Ingrediants = pd.read_csv("Ingredients.csv")
df_CleanTable = pd.read_csv("Final_clean_project_data_Recipe_table.csv")
df_range = pd.read_csv("Rating_categorial.csv")

# %%
df_CleanTable
# Out:
#        Unnamed: 0                                      Name  Rating  \
# 0               0                         Best Banana Bread    96.2
# 1               1                           Bourbon Chicken    91.8
# 2               2          Jo Mama's World Famous Spaghetti    94.6
# 3               3                Creamy Cajun Chicken Pasta    96.8
# 4               4                                Beer Bread    95.8
# ...           ...                                       ...     ...
# 10703       10985                         Shoarma Spice Mix    92.0
# 10704       10986  Perfect Boiled Shrimp and Cocktail Sauce    87.6
# 10705       10987         Crispy & Sweet Blackberry Cobbler    84.4
# 10706       10988     Autumn Pasta with Pumpkin and Sausage    84.4
# 10707       10989                  Best Gingerbread Cookies    88.6
#
#        Rank number  Preparation time in mins  Ingredients number  \
# 0             2282                        70                   8
# ...

# %%
X = df_CleanTable[["Preparation time in mins","Ingredients number"]].values
y = df_CleanTable["Rating_categorial"].values



XTrain, XTest, yTrain, yTest = train_test_split(X, y, random_state=1, test_size=0.25)
#XTrain= XTrain.reshape(-1, 1)
#yTrain= yTrain.reshape(-1, 1)
#XTest = XTest.reshape(-1, 1)

# %%
gnb = GaussianNB()


# Train classifier
gnb.fit(XTrain,yTrain)

y_pred = gnb.predict(XTest)
y_pred_train = gnb.predict(XTrain)

# Print results
print('Accuracy on Train data= ', metrics.accuracy_score(y_true = yTrain, y_pred = y_pred_train))
print('Accuracy on test data= ', metrics.accuracy_score(y_true = yTest, y_pred = y_pred))
# Out:
# Accuracy on Train data=  0.9119661312414394
# Accuracy on test data=  0.9129622711991034

# %%
gnb.class_prior_
# Out:
# array([0.08803387, 0.91196613])

# %%
lrm=linear_model.LogisticRegression()
lrm.fit(df_CleanTable[["Preparation time in mins","Ingredients number"]],df_CleanTable["Rating_categorial"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-7c31fa61e56d> in <module>
# ----> 1 lrm=linear_model.LogisticRegression()
#       2 lrm.fit(df_CleanTable[["Preparation time in mins","Ingredients number"]],df_CleanTable["Rating_categorial"])
#
# NameError: name 'linear_model' is not defined
